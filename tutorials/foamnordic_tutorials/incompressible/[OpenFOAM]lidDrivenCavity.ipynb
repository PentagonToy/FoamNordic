# %% [markdown]
# # [Laminar] Lid-driven Cavity

# %% [markdown]
# ## Preamble

# %%
# Standard Library
import sys
import os
from pathlib import Path
import foamnordic as fno
import numpy as np
import matplotlib.pyplot as plt
import onsaemiro as osm

# %% [markdown]
# ### Directory & Path

# %%
# FoamNordic Project Directory
PROJECT_DIR = Path("/scratch/<allocation-account>/<user>")
CASE_TYPE = "laminar"
CASE_NAME = "lidDrivenCavity"
BASE_DIR = PROJECT_DIR / "Codes" / "FoamNordic"
MAIN_DIR = BASE_DIR / "foamnordic_tutorials" / "incompressible"
OF_SCRIPT_DIR = BASE_DIR / "openfoam_tutorials" / CASE_TYPE / CASE_NAME

# Output Directory
OUTPUT_DIR = MAIN_DIR / "output"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### Configuration

# %%
# HPC configuration
ACCOUNT = "<allocation-account>"
PARTITION = "small"
TIME = "00:15:00"
N_NODES = 1
N_TASKS = 1
CPUS_PER_TASK = 1
MEM_PER_CPU = "4G"

# FoamNordic Slurm configuration
scheduler = fno.Slurm(
    account=ACCOUNT,
    partition=PARTITION,
    time=TIME,
    openfoam=fno.Slurm.openfoam(
        nodes=N_NODES,
        ntasks=N_TASKS,
        cpus_per_task=CPUS_PER_TASK,
        mem_per_cpu=MEM_PER_CPU,
    ),
)

# %%
# FoamNordic configuration
SEED = 42
key = fno.Random.key(seed=SEED, scope="global")

# %% [markdown]
# ## Example - OpenFOAM on FoamNordic (Baseline)

# %% [markdown]
# ### Case Definition

# %%
# Initialize the OpenFOAM case
case = fno.OpenFOAM.Case(
    name=CASE_NAME,
    case_dir=OF_SCRIPT_DIR,
    run_dir=OUTPUT_DIR,
    of_cmd="module load openfoam/2512",
    shell="bash",
    application="pimpleFoam",
)

case.initialize(ranks=N_TASKS, mesh="blockMesh", validate_mesh=True);

# %% [markdown]
# ### Submit Job

# %%
# Connect the OpenFOAM case and SLURM scheduler (launch a longship instance)
#longship = fno.Longship(case=case, scheduler=scheduler) # with scheduler (batch job)
longship = fno.Longship(case=case, scheduler=scheduler) # without scheduler (interactive job)

# Set sail for the OpenFOAM case (submit the job to the HPC cluster)
run = longship.launch(start_timeout=900)
# Out:
# [FoamNordic] Preparing mesh with blockMesh: lidDrivenCavity
# [FoamNordic] Mesh is ready: lidDrivenCavity
# [FoamNordic] Sailing submitted with Job ID: 828741
# [FoamNordic] Sailing has launched with Job ID: 828741
# [FoamNordic] Sailing started at: 2026-08-24T07:42:13
# [FoamNordic] Sailing in background: lidDrivenCavity

# %%
# Wait for the job to complete (polling the job status)
result = run.stop(force=False, timeout=3600, progress=True)

# %%
# Summary of the job result
result.summary(style="compact");
# Out:
# <div style="margin:15px 0; display:inline-block; background:none"><div style="font-family:'Times New Roman', Times, serif; font-weight:bold; color:currentColor; font-size:14px; margin-bottom:10px; text-align:left">lidDrivenCavity Summary</div><table style="border-collapse:collapse; font-family:'Times New Roman', Times, serif; border:none; line-height:1.5; color:currentColor; background:none"><thead><tr><th style="padding:10px 14px; text-align:left; font-weight:bold; color:currentColor; border-top:2.5px solid currentColor; border-bottom:1.2px solid currentColor; font-size:14px; background:none">Job ID</th><th style="padding:10px 14px; text-align:right; font-weight:bold; color:currentColor; border-top:2.5px solid currentColor; border-bottom:1.2px solid currentColor; font-size:14px; background:none">Name</th><th style="padding:10px 14px; text-align:right; font-weight:bold; color:currentColor; border-top:2.5px solid currentColor; border-bottom:1.2px solid currentColor; font-size:14px; background:none">Status</th><th style="padding:10px 14px; text-align:right; font-weight:bold; color:currentColor; border-top:2.5px solid currentColor; border-bottom:1.2px solid currentColor; font-size:14px; background:none">Partition</th><th style="padding:10px 14px; text-align:right; font-weight:bold; color:currentColor; border-top:2.5px solid currentColor; border-bottom:1.2px solid currentColor; font-size:14px; background:none">Node</th><th style="padding:10px 14px; text-align:right; font-weight:bold; color:currentColor; border-top:2.5px solid currentColor; border-bottom:1.2px solid currentColor; font-size:14px; background:none">Elapsed</th></tr></thead><tbody><tr><td style="padding:8px 14px; text-align:left; font-size:13px; color:currentColor; border-bottom:2.5px solid currentColor; background:none">828741</td><td style="padding:8px 14px; text-align:right; font-size:13px; color:currentColor; border-bottom:2.5px solid currentColor; background:none">lidDrivenCavity</td><td style="padding:8px 14px; text-align:right; font-size:13px; color:currentColor; border-bottom:2.5px solid currentColor; background:none">succeeded</td><td style="padding:8px 14px; text-align:right; font-size:13px; color:currentColor; border-bottom:2.5px solid currentColor; background:none">small</td><td style="padding:8px 14px; text-align:right; font-size:13px; color:currentColor; border-bottom:2.5px solid currentColor; background:none">rc4129</td><td style="padding:8px 14px; text-align:right; font-size:13px; color:currentColor; border-bottom:2.5px solid currentColor; background:none">00:00:53</td></tr></tbody></table></div>

# %% [markdown]
# ### Postprocessing

# %%
# Postprocessing
post = result.postprocess

velocity = post.field("U", time_idx=-1)
pressure = post.field("p", time_idx=-1)

print("U shape:", velocity.shape)
print("p shape:", pressure.shape)

statistics = post.statistics(
    ["U", "p"],
    time_idx=-1,
    verbose=True,
)
# Out:
# U shape: (4096, 3)
# p shape: (4096,)
# <div style="margin:15px 0; display:inline-block; background:none"><div style="font-family:'Times New Roman', Times, serif; font-weight:bold; color:currentColor; font-size:14px; margin-bottom:10px; text-align:left">OpenFOAM Field Statistics (t=10)</div><table style="border-collapse:collapse; font-family:'Times New Roman', Times, serif; border:none; line-height:1.5; color:currentColor; background:none"><thead><tr><th style="padding:10px 14px; text-align:left; font-weight:bold; color:currentColor; border-top:2.5px solid currentColor; border-bottom:1.2px solid currentColor; font-size:14px; background:none">Field</th><th style="padding:10px 14px; text-align:right; font-weight:bold; color:currentColor; border-top:2.5px solid currentColor; border-bottom:1.2px solid currentColor; font-size:14px; background:none">Min</th><th style="padding:10px 14px; text-align:right; font-weight:bold; color:currentColor; border-top:2.5px solid currentColor; border-bottom:1.2px solid currentColor; font-size:14px; background:none">Max</th><th style="padding:10px 14px; text-align:right; font-weight:bold; color:currentColor; border-top:2.5px solid currentColor; border-bottom:1.2px solid currentColor; font-size:14px; background:none">Mean</th><th style="padding:10px 14px; text-align:right; font-weight:bold; color:currentColor; border-top:2.5px solid currentColor; border-bottom:1.2px solid currentColor; font-size:14px; background:none">Std</th><th style="padding:10px 14px; text-align:right; font-weight:bold; color:currentColor; border-top:2.5px solid currentColor; border-bottom:1.2px solid currentColor; font-size:14px; background:none">RMS</th></tr></thead><tbody><tr><td style="padding:8px 14px; text-align:left; font-size:13px; color:currentColor; border-bottom:none; background:none">U</td><td style="padding:8px 14px; text-align:right; font-size:13px; color:currentColor; border-bottom:none; background:none">8.131911e-06</td><td style="padding:8px 14px; text-align:right; font-size:13px; color:currentColor; border-bottom:none; background:none">8.736061e-01</td><td style="padding:8px 14px; text-align:right; font-size:13px; color:currentColor; border-bottom:none; background:none">1.765603e-01</td><td style="padding:8px 14px; text-align:right; font-size:13px; color:currentColor; border-bottom:none; background:none">1.458542e-01</td><td style="padding:8px 14px; text-align:right; font-size:13px; color:currentColor; border-bottom:none; background:none">2.290131e-01</td></tr><tr><td style="padding:8px 14px; text-align:left; font-size:13px; color:currentColor; border-bottom:2.5px solid currentColor; background:none">p</td><td style="padding:8px 14px; text-align:right; font-size:13px; color:currentColor; border-bottom:2.5px solid currentColor; background:none">-1.093240e-01</td><td style="padding:8px 14px; text-align:right; font-size:13px; color:currentColor; border-bottom:2.5px solid currentColor; background:none">5.939280e-01</td><td style="padding:8px 14px; text-align:right; font-size:13px; color:currentColor; border-bottom:2.5px solid currentColor; background:none">-2.095064e-02</td><td style="padding:8px 14px; text-align:right; font-size:13px; color:currentColor; border-bottom:2.5px solid currentColor; background:none">3.247379e-02</td><td style="padding:8px 14px; text-align:right; font-size:13px; color:currentColor; border-bottom:2.5px solid currentColor; background:none">3.864552e-02</td></tr></tbody></table></div>
